# %%
#!pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scipy in d:\thi giac may tinh\2\lib\site-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in d:\thi giac may tinh\2\lib\site-packages (from scipy) (1.26.4)

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage

# %%
image_path = 'D:/Thi giac may tinh/image/1.jpg'
image = Image.open(image_path)

# %%
gray_image = image.convert('L')

# %%
image_a = np.array(gray_image)

# %%
blurred_image_a = ndimage.gaussian_filter(image_a, sigma=1, mode="constant")
blurred_image_b = ndimage.gaussian_filter(image_a, sigma=3, mode="constant")
blurred_image_c = ndimage.gaussian_filter(image_a, sigma=5, mode="constant")

# %%
# Out:
# Text(0.5, 1.0, 'sigma=5')

# %%
fig, axs = plt.subplots(2,2, figsize=(10, 8))
plt.subplot(2,2,1)
plt.imshow(gray_image, cmap='gray')
plt.title('Ảnh xám gốc')

plt.subplot(2,2,2)
plt.imshow(blurred_image_a, cmap='gray')
plt.title('sigma=1')

plt.subplot(2,2,3)
plt.imshow(blurred_image_b, cmap='gray')
plt.title('sigma=3')

plt.subplot(2,2,4)
plt.imshow(blurred_image_c, cmap='gray')
plt.title('sigma=5')
# Out:
# Text(0.5, 1.0, 'sigma=5')
