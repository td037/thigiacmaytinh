# %%
# Ctrl + Enter: run code
# Shift + Enter: run code => them mot dong moi

# %%
# Cài đặt
# !pip install Pillow
# !conda install Pillow

# %%
from PIL import Image

# %%
dir = 'D:/thi giac may tinh/image/'

# %%
image_path = dir +'/1.JPG'
print(image_path)
# Out:
# D:/thi giac may tinh/image//1.JPG

# %%
img01 = Image.open(image_path)

# %%
# Hiển thị hình ảnh
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=750x1000>

# %%
print("Định dạng ảnh: ",img01.format)
# Out:
# Định dạng ảnh:  JPEG

# %%
print("Kích thước hình ảnh: ",img01.size)
# Out:
# Kích thước hình ảnh:  (750, 1000)

# %%
new_copy_img01 = dir + '/new_01.JPG'
new_copy2_img01 = dir + '/new_01.PNG'
img01.save(new_copy_img01)
img01.save(new_copy2_img01)

# %%
img01.close()
