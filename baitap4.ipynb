# %%
from PIL import Image
from PIL import Image
from imgtools import *

# %%
link_img = 'D:/Thi giac may tinh/image/5.jpg'

# %%
img = load_image(link_img)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=564x700>

# %%
region = (30, 30, 130, 120)
cropped_image =img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=100x90>

# %%
paste_position = (350, 350)
img.paste(cropped_image, paste_position)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=564x700>
