# %%
from PIL import Image
from imgtools import *
#from IPython.display import display

# %%
link_img = 'D:/Thi giac may tinh/image/6.jpg'

# %%
img = load_image(link_img)
# img = img.resize((250,250))

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=313x410>

# %%
rotated_image = img.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=313x410>

# %%
rotated_image =rotated_image.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=313x410>

# %%
transposed_image = img.transpose(Image.Transpose.ROTATE_90)
display(transposed_image)
# Out:
# <PIL.Image.Image image mode=RGB size=410x313>
