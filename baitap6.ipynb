# %%
from PIL import Image
from imgtools import *

# %%
link_img ='D:/Thi giac may tinh/image/6.jpg'

# %%
img = load_image(link_img)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=313x410>

# %%
gray_image = img.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=313x410>

# %%
red_band, green_band, blue_band =img.split()
display(red_band)
display(green_band)
display(blue_band)
# Out:
# <PIL.Image.Image image mode=L size=313x410>
# <PIL.Image.Image image mode=L size=313x410>
# <PIL.Image.Image image mode=L size=313x410>

# %%
merged_image =  Image.merge("RGB", (red_band, green_band, blue_band))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=313x410>
